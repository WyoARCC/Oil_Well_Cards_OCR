# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from PIL import Image
import os
from pdf2image import convert_from_path

poppler = '/pfs/tc1/project/arcc-students/csloan5/environments/normal/bin/'
directory = '/pfs/tc1/project/arcc-students/OilWellProject2023.Summer/typeOneTestSet/'
filename = os.path.join(directory, '144-0012.pdf_page_1.pdf')

im = convert_from_path(filename, poppler_path=poppler)[0]

plt.imshow(im)

# Get the current reference
ax = plt.gca()
ax.set_axis_off()
ax.figure.set_size_inches(18.5, 10.5)
# Create a Rectangle patch
coords = [886, 500, 50, 13]
rect = Rectangle((coords[0], coords[1]), coords[2], coords[3],linewidth=1,edgecolor='r',facecolor='none')
ax.add_patch(rect)

# %%
#     filename = os.path.splitext(os.path.basename(testFile))[0]
#     pdf = '/pfs/tc1/project/arcc-students/OilWellProject2023.Summer/typeOneTestSet/' + filename
#     im = convert_from_path(pdf, poppler_path='/pfs/tc1/project/arcc-students/csloan5/environments/normal/bin/')[0]

#     # Display the image
#     plt.imshow(im)

#     # Get the current reference
#     ax = plt.gca()
#     ax.set_axis_off()
#     ax.figure.set_size_inches(18.5, 10.5)
#     # Create a Rectangle patch
#     coords = [34,737,9,10]
#     rect = Rectangle((coords[0], coords[1]), coords[2], coords[3],linewidth=1,edgecolor='r',facecolor='none')
#     ax.add_patch(rect)

# %%
for index in range(len(original)):
        line1 = original[index]
        if index + 1 > len(realigned):
            formatted_string = (
                f'{line1[6]:<9}{line1[7]:<9}{line1[8]:<9}{line1[9]:<9}'
                f'{line1[11]}'
                )
        else:
            line2 = realigned[index]
            formatted_string = (
                f'{line1[6]:<9}{line1[7]:<9}{line1[8]:<9}{line1[9]:<9}'
                f'{line1[11]:<56}{line2[6]:<9}{line2[7]:<9}{line2[8]:<9}'
                f'{line2[9]:<9}{line2[11]}'
                )
        print(formatted_string)
