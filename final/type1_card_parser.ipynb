# %%
""" TODO:
    - Fix Init prod and Prod Zone parsing expressions
    - Try changing the parse_lines() function to use if-elif-else rather than 
        multiple if statements.
    - Add parsing expression for Reissue, Formations, Casings
    - Somehow figure out how to extract DSTs and core info --- DONE
    - Find out how to get accuracy level of parsed details.
    - Manually separate type1 cards from the rest ??
    """
    

import csv
import os
import re
import pandas as pd
import argparse
from utils.csv_utils import sort_csv_by_column

# Index positions for each element in a row
# level= 0
# pagenum = 1
# block_num = 2
# par_num = 3
# line_num = 4
# word_num = 5
# left = 6
# top = 7
# width = 8
# height = 9
# conf = 10
# text = 11

def load_csv_filenames(csv_dir):
    """Takes a path to a directory with CSVs, then adds all of the paths of
    the CSV files in that directory to the filenames list, which is returned.
    
    Parameters:
        csv_dir - String containing file system location of CSV files.
    Returns:
        filenames - Updated list of CSV file paths.
    """
    filenames = []
    # Scan recursively over all tsv files in a directory
    for folder, subfolders, files in os.walk(csv_dir):
        for file in files:
            if file.endswith('.csv'):
                #Add all the .pdf filenames to a list
                filename = os.path.join(folder, file)
                filenames.append(filename)
                
    return filenames

def left_is_close(list1, list2, dist):
    # Make the list elements numerical so numerical comparisons will be easier
    list1 = list(map(transform_element, list1))
    list2 = list(map(transform_element, list2))
    
    # First determine the leftmost text out of the two, then use that to 
    # check if the words should be joined together.
    if list1[6] < list2[6]:
        return (abs((list1[6] + list1[8]) - list2[6]) <= dist)
    else: 
        return (abs((list2[6] + list2[8]) - list1[6]) <= dist)
    
def top_is_close(line1, line2, dist):
    # Determine if the top coordinates of the two lines are within dist of
    # each other
    return (abs((int(line1[7]) + int(line1[9])) - 
                (int(line2[7]) + int(line2[9]))) <= dist)

def transform_element(item):
    # Attempts to change the item's to a float. If that doesn't work then the
    # item is returned as is. If it does work, then it will then either return
    # the float or change the float to an int and return that if possible.
    try:
        num = float(item)
    except (TypeError, ValueError):
        return item
    else:
        if num.is_integer():
            return int(num)
        else:
            return num


def combine_lines(list1, list2):
    # Calculate the new coordinate information for combined text
    left = min(list1[6], list2[6])
    top = min(list1[7], list2[7])
    height = max(list1[9], list2[9])
    conf = ((list1[10] / 100) * (list2[10]/ 100)) * 100
    
    # Ensure that the lists can be passed to this function in any order
    if left == list1[6]:
        width = abs((list2[6] + list2[8]) - list1[6])
        text = f'{list1[11]} {list2[11]}'
    else:
        width = abs((list1[6] + list1[8]) - list2[6])
        text = f'{list2[11]} {list1[11]}'

    # Change the elements of the new list to all strings again, and return
    combined_list = list1[:6].copy()
    combined_list.extend([left, top, width, height, conf, text])

    return combined_list
    
def clean_dataframe(df):
    # Remove all text entries that are set as 'Nan'
    tmp_df = df.dropna(subset=['text'])
    # Filter out the rows of every text entry that contains spaces and/or '|'
    filtered = tmp_df[tmp_df.text.str.fullmatch('\ *\|?')].index
    # Drop the rows that were just filtered out
    filtered_df = tmp_df.drop(filtered)
    mask = (filtered_df.width * filtered_df.height) < 100
    new_df = filtered_df[~mask]
    return new_df

def realign_text(orig_df, left_dist_def, top_dist_def):
    # Clean the dataframe
    df = clean_dataframe(orig_df)
    # Convert the dataframe to a list
    ref_list = df.values.tolist()
    realigned = ref_list.copy()
    # Keep track of whether or not any changes were made in the latest 
    # iteration. Initialize to True so the while-loop will start.
    modified = True
    # Continue realigning the text until no changes are made
    while modified:
        # Reset to false for beginning of loop
        modified = False
        # Compare every row to every other row only once. Do not compare a row 
        # to itself
        for index, item1 in enumerate(ref_list):
            for item2 in ref_list[index+1:]:
                # Searching for special entires
                if re.search('well.class:?', item1[11]):
                    left_dist = left_dist_def + 60
                elif re.search('well.?(#|no)?:?\ ?.*', item1[11], re.IGNORECASE):
                    if not re.search('(wells.*|.*ask\ us.*|well.class.*|elev\ ?chgd.*|rocky.mount)', item1[11], re.IGNORECASE):
                        left_dist = left_dist_def + 80
                elif re.search('(OPR|OPERATOR):?\ ?.*', item1[11], re.IGNORECASE):
                    left_dist = left_dist_def + 100
                elif re.search('CSG:?\ ?', item1[11], re.IGNORECASE):
                    left_dist = left_dist_def + 70
                else:
                    left_dist = left_dist_def

                top_dist = top_dist_def
                # Check if the two rows being compared are 'close'
                if top_is_close(item1, item2, top_dist) and left_is_close(item1, item2, left_dist):
                    # The realigned list is going to become shorter, so we need to
                    # ensure that the item we are comparing is still in the
                    # realigned list.
                    try:
                        modified = True # Changes have been made
                        # Get the positions of the two lines of text that will be
                        # combined
                        first_pos = realigned.index(item1)
                        second_pos = realigned.index(item2)
                    except ValueError:
                        # At least one of the lines were removed
                        continue

                    # Ensure that we combine the text in the right order
                    if int(item1[6]) < int(item2[6]):
                        realigned[first_pos] = combine_lines(item1, item2)
                        realigned.pop(second_pos)
                    else:
                        realigned[second_pos] = combine_lines(item1, item2)
                        realigned.pop(first_pos)
        ref_list = realigned.copy()
                
    return pd.DataFrame(data=realigned, columns=[
        'level', 'page_num', 'block_num', 'par_num', 'line_num', 'word_num',
        'left', 'top', 'width', 'height', 'conf', 'text'
        ])
        
def parse_lines(df, parsed):
    for line in df.itertuples(index=False):
        text = line[11]
        # Well Name / Number
        if re.search('well.?(#|no)?:?\ ?.*', text, re.IGNORECASE):
            if not re.search('(wells.*|.*ask\ us.*|well.class.*|elev\ ?chgd.*|rocky.mount)', text, re.IGNORECASE):
                text = re.sub('[=~!@#$%^&*\(\)\[\]\{\}\\\/;]', '', text) # remove any symbols
                parsed['WellName'] += re.split('well.?(#|no)?[:;]?\ ?', text, re.IGNORECASE)[-1]
            
        # Township and range
        if re.search('twp\.?\ ?[0-9A-Z]{1,2}n[\-\ ][0-9A-Z]{1,3}w?', text, re.IGNORECASE):
            parsed['Township'] = re.search('twp\.?\ ?[0-9A-Z]{1,2}n', text, re.IGNORECASE).group(0)
            parsed['Range'] = re.sub(parsed['Township'], '', text)
            parsed['Range'] = parsed['Range'].replace('-', '')
            
        # Section
        if re.search('(section|sec)\.?\ ?[0-9]{1,2}', text, re.IGNORECASE):
            if parsed['Section'] == '':  
                parsed['Section'] = re.search('(section|sec)\.?\ ?[0-9]{1,2}', text, re.IGNORECASE).group(0);
            
        # Quarter-Quarter info
        if re.search('(c|c\/2)?\ ?(((n|e|s|w)\/2)|(ne|nw|se|sw)\ ?){2,3}.*', text, re.IGNORECASE):
             parsed['QtrQtr'] = re.search('(c|c\/2)?\ ?(((n|e|s|w)\/2)|(ne|nw|se|sw)\ ?){2,3}', text, re.IGNORECASE).group(0)
            
        # NS SW Footage
        if re.search('\(?[0-9]{1,4}\ ?(n\/s|fn[l1i]|s\/n)\ ?[0-9]{1,4}\ ?(e\/w|fw[l1i]|w\/e)\)?', text):
            if parsed['NSFootage'] == '' and parsed['EWFootage'] == '':
                parsed['NSFootage'] = re.search('\(?[0-9]{1,4}\ ?(n\/s|fn[l1i]|s\/n)\ ?', text).group(0)
                parsed['EWFootage'] = re.split('\(?[0-9]{1,4}\ ?(n\/s|fn[l1i]|s\/n)\ ?', text)[-1]
        
        # Operator
        if re.search('(opr|operator):?\ ?.*', text, re.IGNORECASE):
            if parsed['Operator'] == '':
                if re.search("well", text, re.IGNORECASE):
                    oprtxt = re.split('well', text, re.IGNORECASE)[0]
                else:
                    oprtxt = text
                parsed['Operator'] = re.split('(opr|operator):?\ ?', oprtxt, re.IGNORECASE)[-1]
            
        # Spud Date
        if re.search('spud:?\ ?[0-9]{1,2}(\/|-)[0-9]{1,2}(\/|-)[0-9]{2,4}', text, re.IGNORECASE):
            parsed['SpudDate'] = re.split('spud:?\ ?', text, re.IGNORECASE)[-1]
            
        # Completion Date
        if re.search('(comp|compl):?\ ?[0-9]{1,2}(\/|-)[0-9]{1,2}(\/|-)[0-9]{2,4}', text, re.IGNORECASE):
            parsed['CompDate'] = re.split('(comp|compl):?\ ?', text, re.IGNORECASE)[-1]
            
        # Elevation
        if re.search('(elev|el):?\ ?[0-9]+.*', text, re.IGNORECASE):
            parsed['Elevation'] = re.split('(elev|el):?\ ?', text, re.IGNORECASE)[-1]
            
        # API number
        if re.search('(api|idn)?:?\ ?49[-~]?[0-9]{3}[-~]?[0-9]{5}', text, re.IGNORECASE):
            parsed['APINum'] = re.search('49[-~]?[0-9]{3}[-~]?[0-9]{5}', text).group(0)
            
        # Total Depth
        if re.search('(TD:?\ ?[0-9]{3,4}|[0-9]{3,4}\ ?TD)', text):
            parsed['TotalDepth'] = ''.join(re.split('(?!TD)', text))
            
        # Plug Back
        if re.search('PB:?\ ?[0-9]{3,4}', text):
            parsed['PlugBackDepth'] = re.split('PB:?\ ?', text)[-1]
        
        # Initial Production
        if re.search('(init\ ?prod:?\ ?|initial\ ?production:?\ ?|ip:)\ ?.*',text, re.IGNORECASE):
            if re.search('(prod\ ?zone|production\ ?zone|prod):?\ ?.*',text, re.IGNORECASE):
                parsed['InitProd'] = re.split('(init\ ?prod|initial\ ?production|IP):?\ ?', text, re.IGNORECASE)[-1]
            
        # Production Zone
        if re.search('(prod\ ?zone|production\ ?zone|prod):?\ ?.*',text, re.IGNORECASE):
            if not re.search('(init\ ?prod:?\ ?|initial\ ?production:?\ ?|ip:)\ ?.*',text, re.IGNORECASE):
                parsed['ProdZone'] = re.split('(prod\ ?zone|production\ ?zone|prod):?\ ?', text, re.IGNORECASE)[-1]
            
        # Card Number
        if re.search('(wy)?[0-9]{2}-?[0-9]{6}',text, re.IGNORECASE):
            if not re.search('.*Replaces.*', text, re.IGNORECASE):
                parsed['CardNumber'] = text
        
        # Well Status/Class
        if re.search('well\ class:?\ ?', text, re.IGNORECASE):
            parsed['WellStatus'] = re.split('well\ class:?\ ?', text, re.IGNORECASE)[-1]
        
        # Reissued information
        if re.search('(REISSUE|Replace)', text, re.IGNORECASE):
            parsed['Reissued'] += ' ' + text
            
        if re.search('CSG:?\ ?', text, re.IGNORECASE):
            parsed['Casing'] = text
            
    return parsed
    
def setLocation(parsed):
        # Make sure to separate the township, range, and section from the pool
        # and county
        if len(parsed['Location']) > 0:
            parsed['Location'] = ', ' + parsed['Location']
        # Set township, range and section
        if parsed['Section']:
            parsed['Location'] = ' ' + parsed['Section'] + parsed['Location']
        if parsed['Range']:
            parsed['Location'] = ' ' + parsed['Range'] + parsed['Location']
        if parsed['Township']:
            parsed['Location'] = parsed['Township'] + parsed['Location']
        if parsed['QtrQtr']:
            parsed['Location'] = parsed['Location'] + ' QtrQtr: ' + parsed['QtrQtr']
        
        # Remove any double spaces
        parsed['Location'] = parsed['Location'].replace('  ', ' ')
        
        return parsed
    
def setLocationFootage(parsed):
        if parsed['NSFootage']:
            parsed['LocationFootage'] += parsed['NSFootage']
        if parsed['EWFootage']:
            parsed['LocationFootage'] += ' ' + parsed['EWFootage']
        
        # Remove any double spaces
        parsed['LocationFootage'] = parsed['LocationFootage'].replace('  ', ' ')
        
        return parsed
            
def inside_block(line, left, right, top, bottom):
    if line[6] < left or line[6] > right or line[7] < top or line[7] > bottom:
        return False
    else:
        return True    
def main():
    # Parse input and output directory options
    argParser = argparse.ArgumentParser()
    argParser.add_argument("-i", "--input", required=True,
                        help="Path to directory containing TSV files")
    argParser.add_argument("-o", "--output", required=True,
                        help="File path that CSV will be outputted to")
    args = vars(argParser.parse_args())
    
    
    # Make sure that the output is a .csv file
    if args["output"][-4:] != '.csv':
        print("ERROR: Output file must be .csv!", file=sys.stderr)
        return

    # Create the .csv file
    output_csv = pd.DataFrame(columns=['DocumentID','APINum','WellName',
        'Operator','Location','Township','Range','Section','NSFootage','EWFootage','QtrQtr',
        'LocationFootage','Elevation','SpudDate','CompDate','TDFormation','TotalDepth',
        'PlugBackDepth','Casing','InitProd','ProdZone','CardNumber','WellStatus','Reissued',
        'DSTS_Cores'])
    
    filenames = load_csv_filenames(args["input"])
    
    exception_count = 0
    print("Exceptions:")
    for index, file in enumerate(filenames):
        CardDetails = {'DocumentID':os.path.basename(file),\
        'APINum':'','WellName':'','Operator':'','Location':'',\
        'Township':'','Range':'','Section':'','NSFootage':'',\
        'EWFootage':'','QtrQtr':'','LocationFootage':'','Elevation':'',\
        'SpudDate':'','CompDate':'','TDFormation':'','TotalDepth':'',\
        'PlugBackDepth':'','Casing':'','InitProd':'','ProdZone':'',\
        'CardNumber':'','WellStatus':'','Reissued':'','DSTS_Cores':''}
        
        # Check that we are working on the correct files
        if not file.endswith('.csv'):
            continue
            
        # Read in the CSV file
        try:
            csvfile = pd.read_csv(file, on_bad_lines='skip')
        except Exception as e:
            print(f"File number: {index}, Exception: {e}, file: {file}")
            exception_count +=1
            continue
    
        # Change the text column in the csv to be all strings.
        csvfile.dropna()
        csvfile['text'] = csvfile['text'].apply(str)
        
        #Code to remove all the "nan"s that show up in the output
        mask = csvfile['text'] == 'nan'
        csvfile = csvfile[~mask]
        
        csvfile['text'] = csvfile['text'].replace("['~`!=\_%*@\^$]", "", regex=True)
        csvfile['text'] = csvfile['text'].replace(";", ":", regex=True)
        
        Formations = ""
        DSTs_and_Cores = ""
        # Grab DSTS and Cores Text section before realigning.
        for line in csvfile.itertuples(index=False):
            # If it is inside the DST block
            if inside_block(line, 300, 680, 190, 700):
                # Make sure we don't go to far down
                if re.search("([cC]ontr):?", line[11]):
                    continue

                if DSTs_and_Cores == "":
                    DSTs_and_Cores = line[11]
                else:
                    DSTs_and_Cores += ' ' + line[11]

            # Else if it is inside the TOPs formations block
            elif inside_block(line, 0, 280, 190, 540):
                if Formations == "":
                    Formations = line[11]
                else:
                    Formations += ' ' + line[11]
        
        # Realign the text
        realigned = realign_text(csvfile, left_dist_def=30, top_dist_def=20)
        realigned.dropna()
        # Find any matching text lines
        parsed = parse_lines(realigned, CardDetails)
        # Set the location information
        parsed = setLocation(parsed)
        parsed = setLocationFootage(parsed)
        
        # Replace any occurence of & in these names with 8
        parsed["WellName"] = parsed["WellName"].replace("&", "8")
        parsed["Operator"] = parsed["Operator"].replace("&", "8")
        
        # Clean up DST and Core info
        DSTs_and_Cores = DSTs_and_Cores.replace("[\n\t\r]", "")
        parsed["DSTS_Cores"] = DSTs_and_Cores.replace("  ", " ")
        
        # Add Formation Tops Info
        parsed["TDFormation"] = Formations.replace("  ", " ")
        
        
        # Append parsed card information to spreadsheet
        df_parsed = pd.DataFrame([parsed])
        output_csv = pd.concat([output_csv, df_parsed], ignore_index=True)

    # Output the csv file
    output_csv.to_csv(args["output"], index=False)
    sort_csv_by_column(args["output"], 0, True)
    
    print("Done parsing cards")
    print(f"Number of exceptions thrown while parsing: {exception_count}")
    return

    
# if __name__ =='__main__':
#     main()

# %%
########################################################################3
# boundingBox = True
boundingBox = False
########################################################################
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from PIL import Image
from pdf2image import convert_from_path
pd.set_option('expand_frame_repr', False)

imgDir = '/pfs/tc1/project/arcc-students/OilWellProject2023.Summer/typeOne/'
boxNo = 'Box1'
imgFile = '320-0234.pdf_page_1.pdf'
poppler = '/pfs/tc1/project/arcc-students/csloan5/environments/GPU_env/bin/'
image = convert_from_path(imgDir+imgFile, poppler_path=poppler)[0]

files = load_csv_filenames('/pfs/tc1/project/arcc-students/OilWellProject2023.Summer/Type_1_CSVs/')


if boundingBox:
    plt.imshow(image)

    # Get the current reference
    ax = plt.gca()
    ax.set_axis_off()
    ax.figure.set_size_inches(18.5, 10.5)
    # Create a Rectangle patch

    #         Left  Top  width  height
    coords = [43, 66, 104, 15]
    rect = Rectangle((coords[0], coords[1]), coords[2], coords[3], linewidth=1, edgecolor='r', facecolor='none')
    ax.add_patch(rect)
else:
    image.show()

csv_dir = os.path.join('/pfs/tc1/project/arcc-students/OilWellProject2023.Summer/ConvertedCSVFiles/', boxNo)
csv_filename = imgFile + '.csv'

# Read in the TSV file
try:
    csvfile = pd.read_csv(os.path.join(csv_dir, csv_filename), on_bad_lines='skip')
except Exception as e:
    print(e, csv_filename)

csvfile['text'] = csvfile['text'].apply(str)
mask = csvfile['text'] == 'nan'
csvfile = csvfile[~mask]

# Remove any unwanted symbols
csvfile['text'] = csvfile['text'].replace("['~`!=]", "", regex=True)
csvfile['text'] = csvfile['text'].replace(";", ":", regex=True)


# for line in csvfile.itertuples(index=False):
#     print (f"left: {line[6]}, width: {line[8]}, top: {line[7]}, height: {line[9]}, text: {line[11]}\t\t\t{line[6]}, {line[7]}, {line[8]}, {line[9]}")


realigned = realign_text(csvfile, left_dist_def=50, top_dist_def=20)
for line in realigned.itertuples(index=False):
    print (f"left: {line[6]}, width: {line[8]}, top: {line[7]}, height: {line[9]}, text: {line[11]}")



CardDetails = {'DocumentID':os.path.basename(imgFile),\
        'APINum':'','WellName':'','Operator':'','Location':'',\
        'Township':'','Range':'','Section':'','NSFootage':'',\
        'EWFootage':'','QtrQtr':'','LocationFootage':'','Elevation':'',\
        'SpudDate':'','CompDate':'','TDFormation':'','TotalDepth':'',\
        'PlugBackDepth':'','Casing':'','InitProd':'','ProdZone':'',\
        'CardNumber':'','WellStatus':'','Reissued':'','DSTS_Cores':''}

Formations = ""
DSTs_and_Cores = ""
# Grab DSTS and Cores Text section before realigning.
for line in csvfile.itertuples(index=False):
    # If it is inside the DST block
    if inside_block(line, 300, 680, 190, 700):
        # Make sure we don't go to far down
        if re.search("([cC]ontr):?", line[11]):
            continue
            
        if DSTs_and_Cores == "":
            DSTs_and_Cores = line[11]
        else:
            DSTs_and_Cores += ' ' + line[11]
            
    # Else if it is inside the TOPs formations block
    elif inside_block(line, 0, 280, 190, 700):
        if Formations == "":
            Formations = line[11]
        else:
            Formations += ' ' + line[11]


parsed = parse_lines(realigned, CardDetails)
parsed = setLocation(parsed)
parsed = setLocationFootage(parsed)

# Add DST and Core information
parsed["DSTS_Cores"] = DSTs_and_Cores.replace('  ', ' ')

# Add TD Formation information
parsed["TDFormation"] = Formations.replace('  ', ' ')

print(f"API: {parsed['APINum']}\nName: {parsed['WellName']}\nOPR: {parsed['Operator']}\nLocation: {parsed['Location']}")
print(f"Township: {parsed['Township']}\nRange: {parsed['Range']}\nSection: {parsed['Section']}")
print(f"NS: {parsed['NSFootage']}\nEW: {parsed['EWFootage']}\nQtrQtr: {parsed['QtrQtr']}")
print(f"LocationFootage: {parsed['Location']}\nElevation: {parsed['Elevation']}\nSPUD: {parsed['SpudDate']}")
print(f"Comp: {parsed['CompDate']}\nFormations: {parsed['TDFormation']}\nTD: {parsed['TotalDepth']}")
print(f"PBTD: {parsed['PlugBackDepth']}\nCasing: {parsed['Casing']}\nInitProd: {parsed['InitProd']}")
print(f"ProdZone: {parsed['ProdZone']}\nCardNumber: {parsed['CardNumber']}\nStatus: {parsed['WellStatus']}")
print(f"Reissued: {parsed['Reissued']}\nDSTS_Cores: {parsed['DSTS_Cores']}")
# Out:
# left: 0, width: 1208, top: 0, height: 803, text: nan			0, 0, 1208, 803
# left: 578, width: 96, top: 62, height: 18, text: nan			578, 62, 96, 18
# left: 578, width: 96, top: 62, height: 18, text: nan			578, 62, 96, 18
# left: 578, width: 96, top: 62, height: 18, text: nan			578, 62, 96, 18
# left: 578, width: 96, top: 62, height: 18, text: REISSUE			578, 62, 96, 18
# left: 124, width: 948, top: 87, height: 92, text: nan			124, 87, 948, 92
# left: 125, width: 841, top: 87, height: 42, text: nan			125, 87, 841, 42
# left: 125, width: 841, top: 87, height: 17, text: nan			125, 87, 841, 17
# left: 125, width: 78, top: 87, height: 17, text: STATE:			125, 87, 78, 17
# left: 211, width: 110, top: 87, height: 17, text: WYOMING			211, 87, 110, 17
# left: 829, width: 137, top: 87, height: 17, text: 12-27N-114W			829, 87, 137, 17
# left: 125, width: 817, top: 112, height: 17, text: nan			125, 112, 817, 17
# left: 125, width: 98, top: 112, height: 17, text: COUNTY:			125, 112, 98, 17
# left: 233, width: 112, top: 112, height: 17, text: SUBLETTE			233, 112, 112, 17
# left: 828, width: 26, top: 112, height: 17, text: SE			828, 112, 26, 17
# left: 864, width: 35, top: 112, height: 17, text: NW			864, 112, 35, 17
# left: 907, width: 35, top: 112, height: 17, text: SW			907, 112, 35, 17
# left: 124, width: 948, top: 136, height: 43, text: nan			124, 136, 948, 43
# left: 124, width: 948, top: 136, height: 18, text: nan			124, 136, 948, 18
# left: 124, width: 42, top: 137, height: 16, text: API:			124, 137, 42, 16
# left: 201, width: 50, top: 145, height: 4, text: 49-035-:			201, 145, 50, 4
# left: 829, width: 47, top: 137, height: 17, text: 1673			829, 137, 47, 17
# left: 884, width: 39, top: 137, height: 17, text: FSL			884, 137, 39, 17
# left: 931, width: 36, top: 137, height: 17, text: 883			931, 137, 36, 17
# left: 975, width: 45, top: 137, height: 16, text: FWL			975, 137, 45, 16
# left: 1028, width: 44, top: 136, height: 17, text: SEC			1028, 136, 44, 17
# left: 125, width: 851, top: 161, height: 18, text: nan			125, 161, 851, 18
# left: 125, width: 69, top: 162, height: 16, text: FIELD:			125, 162, 69, 16
# left: 203, width: 124, top: 162, height: 16, text: HOGSBACK			203, 162, 124, 16
# left: 336, width: 50, top: 162, height: 17, text: UNIT			336, 162, 50, 17
# left: 827, width: 95, top: 162, height: 17, text: STATUS:			827, 162, 95, 17
# left: 931, width: 45, top: 161, height: 17, text: GAS			931, 161, 45, 17
# left: 124, width: 650, top: 186, height: 68, text: nan			124, 186, 650, 68
# left: 124, width: 650, top: 186, height: 68, text: nan			124, 186, 650, 68
# left: 124, width: 190, top: 186, height: 17, text: nan			124, 186, 190, 17
# left: 124, width: 63, top: 186, height: 17, text: WELL			124, 186, 63, 17
# left: 194, width: 80, top: 186, height: 17, text: CLASS:			194, 186, 80, 17
# left: 283, width: 31, top: 186, height: 17, text: DG			283, 186, 31, 17
# left: 125, width: 184, top: 211, height: 17, text: nan			125, 211, 184, 17
# left: 125, width: 70, top: 211, height: 17, text: MOBIL			125, 211, 70, 17
# left: 203, width: 35, top: 211, height: 17, text: OIL			203, 211, 35, 17
# left: 246, width: 63, top: 211, height: 17, text: CORP			246, 211, 63, 17
# left: 477, width: 297, top: 236, height: 18, text: nan			477, 236, 297, 18
# left: 477, width: 102, top: 237, height: 17, text: T26X-12G			477, 237, 102, 17
# left: 587, width: 128, top: 236, height: 18, text: HOGSBACK			587, 236, 128, 18
# left: 724, width: 50, top: 237, height: 17, text: UNIT			724, 237, 50, 17
# left: 124, width: 1005, top: 266, height: 11, text: nan			124, 266, 1005, 11
# left: 124, width: 1005, top: 266, height: 11, text: nan			124, 266, 1005, 11
# left: 124, width: 1005, top: 266, height: 11, text: nan			124, 266, 1005, 11
# left: 124, width: 1005, top: 266, height: 11, text:  			124, 266, 1005, 11
# left: 124, width: 951, top: 317, height: 120, text: nan			124, 317, 951, 120
# left: 124, width: 566, top: 317, height: 20, text: nan			124, 317, 566, 20
# left: 124, width: 566, top: 317, height: 20, text: nan			124, 317, 566, 20
# left: 124, width: 61, top: 317, height: 20, text: SPUD			124, 317, 61, 20
# left: 194, width: 3, top: 322, height: 11, text: :			194, 322, 3, 11
# left: 205, width: 110, top: 317, height: 17, text: 07/31/1999			205, 317, 110, 17
# left: 322, width: 66, top: 317, height: 20, text: COMP			322, 317, 66, 20
# left: 397, width: 2, top: 322, height: 11, text: :			397, 322, 2, 11
# left: 408, width: 111, top: 317, height: 17, text: 09/23/1999			408, 317, 111, 17
# left: 527, width: 56, top: 317, height: 17, text: ELEV			527, 317, 56, 17
# left: 591, width: 3, top: 322, height: 11, text: :			591, 322, 3, 11
# left: 603, width: 48, top: 318, height: 16, text: 7770			603, 318, 48, 16
# left: 659, width: 31, top: 317, height: 17, text: GR			659, 317, 31, 17
# left: 124, width: 934, top: 341, height: 46, text: nan			124, 341, 934, 46
# left: 124, width: 934, top: 341, height: 21, text: nan			124, 341, 934, 21
# left: 124, width: 41, top: 341, height: 20, text: TD			124, 341, 41, 20
# left: 156, width: 11, top: 337, height: 31, text: :			156, 337, 11, 31
# left: 174, width: 48, top: 342, height: 16, text: 8700			174, 342, 48, 16
# left: 230, width: 124, top: 342, height: 20, text: (08/20/1999)			230, 342, 124, 20
# left: 363, width: 66, top: 341, height: 21, text: FM/TD			363, 341, 66, 21
# left: 438, width: 2, top: 346, height: 12, text: :			438, 346, 2, 12
# left: 450, width: 79, top: 342, height: 16, text: MUDDY			450, 342, 79, 16
# left: 536, width: 60, top: 342, height: 16, text: /SILT/			536, 342, 60, 16
# left: 603, width: 36, top: 342, height: 16, text: SH/			603, 342, 36, 16
# left: 647, width: 36, top: 342, height: 16, text: SD/			647, 342, 36, 16
# left: 689, width: 71, top: 342, height: 20, text: PBTD			689, 342, 71, 20
# left: 752, width: 9, top: 337, height: 31, text: :			752, 337, 9, 31
# left: 769, width: 49, top: 342, height: 16, text: 8540			769, 342, 49, 16
# left: 825, width: 43, top: 342, height: 16, text: TVD			825, 342, 43, 16
# left: 877, width: 3, top: 346, height: 11, text: :			877, 346, 3, 11
# left: 888, width: 49, top: 342, height: 16, text: 8543			888, 342, 49, 16
# left: 944, width: 45, top: 342, height: 19, text: DTD			944, 342, 45, 19
# left: 998, width: 2, top: 346, height: 12, text: :			998, 346, 2, 12
# left: 1009, width: 49, top: 342, height: 16, text: 8700			1009, 342, 49, 16
# left: 124, width: 666, top: 366, height: 21, text: nan			124, 366, 666, 21
# left: 124, width: 90, top: 366, height: 20, text: CONTR			124, 366, 90, 20
# left: 205, width: 11, top: 362, height: 31, text: :			205, 362, 11, 31
# left: 223, width: 57, top: 366, height: 17, text: CAZA			223, 366, 57, 17
# left: 288, width: 101, top: 366, height: 17, text: DRILLING			288, 366, 101, 17
# left: 398, width: 37, top: 366, height: 17, text: RIG			398, 366, 37, 17
# left: 443, width: 11, top: 367, height: 15, text: #			443, 367, 11, 15
# left: 462, width: 22, top: 367, height: 16, text: 72			462, 367, 22, 16
# left: 492, width: 187, top: 366, height: 21, text: (DIRECTIONALLY			492, 366, 187, 21
# left: 688, width: 102, top: 366, height: 21, text: DRILLED)			688, 366, 102, 21
# left: 124, width: 951, top: 391, height: 46, text: nan			124, 391, 951, 46
# left: 124, width: 951, top: 391, height: 22, text: nan			124, 391, 951, 22
# left: 120, width: 62, top: 387, height: 32, text: PROJ			120, 387, 62, 32
# left: 194, width: 109, top: 391, height: 21, text: DEPTH/FM			194, 391, 109, 21
# left: 312, width: 3, top: 396, height: 12, text: :			312, 396, 3, 12
# left: 324, width: 48, top: 392, height: 17, text: 7732			324, 392, 48, 17
# left: 380, width: 112, top: 391, height: 17, text: FRONTIER			380, 391, 112, 17
# left: 500, width: 11, top: 392, height: 17, text: 2			500, 392, 11, 17
# left: 519, width: 59, top: 391, height: 21, text: PROJ			519, 391, 59, 21
# left: 585, width: 44, top: 391, height: 18, text: TVD			585, 391, 44, 18
# left: 637, width: 3, top: 396, height: 12, text: :			637, 396, 3, 12
# left: 648, width: 49, top: 392, height: 17, text: 7650			648, 392, 49, 17
# left: 704, width: 35, top: 391, height: 22, text: (ST			704, 391, 35, 22
# left: 747, width: 60, top: 391, height: 18, text: APPD			747, 391, 60, 18
# left: 816, width: 51, top: 391, height: 17, text: PMT:			816, 391, 51, 17
# left: 876, width: 118, top: 391, height: 21, text: 06/10/1999)			876, 391, 118, 21
# left: 1003, width: 72, top: 391, height: 21, text: LEASE			1003, 391, 72, 21
# left: 128, width: 355, top: 416, height: 21, text: nan			128, 416, 355, 21
# left: 128, width: 60, top: 416, height: 21, text: TYPE:			128, 416, 60, 21
# left: 197, width: 75, top: 417, height: 16, text: OTHER			197, 417, 75, 16
# left: 284, width: 87, top: 417, height: 20, text: TARGET			284, 417, 87, 20
# left: 379, width: 50, top: 417, height: 20, text: OBY:			379, 417, 50, 20
# left: 438, width: 45, top: 417, height: 16, text: GAS			438, 417, 45, 16
# left: 124, width: 960, top: 466, height: 70, text: nan			124, 466, 960, 70
# left: 124, width: 960, top: 466, height: 70, text: nan			124, 466, 960, 70
# left: 124, width: 934, top: 466, height: 18, text: nan			124, 466, 934, 18
# left: 124, width: 49, top: 467, height: 16, text: 8700			124, 467, 49, 16
# left: 181, width: 44, top: 467, height: 16, text: DTD			181, 467, 44, 16
# left: 232, width: 66, top: 466, height: 18, text: COMP			232, 466, 66, 18
# left: 305, width: 110, top: 466, height: 18, text: 09/23/1999			305, 466, 110, 18
# left: 423, width: 11, top: 468, height: 15, text: #			423, 468, 11, 15
# left: 442, width: 33, top: 467, height: 17, text: 001			442, 467, 33, 17
# left: 485, width: 33, top: 467, height: 17, text: IPF			485, 467, 33, 17
# left: 526, width: 42, top: 467, height: 17, text: OIL:			526, 467, 42, 17
# left: 584, width: 4, top: 467, height: 17, text: 0			584, 467, 4, 17
# left: 596, width: 45, top: 467, height: 17, text: BPD			596, 467, 45, 17
# left: 649, width: 53, top: 467, height: 17, text: GAS:			649, 467, 53, 17
# left: 711, width: 48, top: 467, height: 17, text: 2000			711, 467, 48, 17
# left: 767, width: 63, top: 467, height: 17, text: MCFD			767, 467, 63, 17
# left: 837, width: 56, top: 467, height: 17, text: WTR:			837, 467, 56, 17
# left: 902, width: 11, top: 467, height: 17, text: 0			902, 467, 11, 17
# left: 922, width: 44, top: 467, height: 17, text: BBL			922, 467, 44, 17
# left: 974, width: 40, top: 467, height: 16, text: FTP			974, 467, 40, 16
# left: 1022, width: 36, top: 467, height: 16, text: 500			1022, 467, 36, 16
# left: 125, width: 959, top: 491, height: 22, text: nan			125, 491, 959, 22
# left: 125, width: 63, top: 491, height: 17, text: PROD			125, 491, 63, 17
# left: 194, width: 67, top: 491, height: 17, text: ZONE:			194, 491, 67, 17
# left: 271, width: 58, top: 492, height: 16, text: PERF			271, 492, 58, 16
# left: 336, width: 119, top: 492, height: 21, text: (FRONTIER			336, 492, 119, 21
# left: 464, width: 18, top: 492, height: 20, text: 2)			464, 492, 18, 20
# left: 490, width: 104, top: 492, height: 17, text: 7295-7588			490, 492, 104, 17
# left: 603, width: 57, top: 492, height: 17, text: PERF			603, 492, 57, 17
# left: 668, width: 88, top: 492, height: 21, text: (MUDDY			668, 492, 88, 21
# left: 762, width: 62, top: 492, height: 17, text: /SILT/			762, 492, 62, 17
# left: 831, width: 37, top: 492, height: 17, text: SH/			831, 492, 37, 17
# left: 875, width: 43, top: 492, height: 21, text: SD/)			875, 492, 43, 21
# left: 926, width: 105, top: 492, height: 17, text: 8138-8380			926, 492, 105, 17
# left: 1040, width: 4, top: 496, height: 14, text: :			1040, 496, 4, 14
# left: 1053, width: 31, top: 491, height: 17, text: NO			1053, 491, 31, 17
# left: 124, width: 626, top: 516, height: 20, text: nan			124, 516, 626, 20
# left: 124, width: 78, top: 516, height: 17, text: CORES			124, 516, 78, 17
# left: 210, width: 31, top: 516, height: 17, text: OR			210, 516, 31, 17
# left: 250, width: 57, top: 516, height: 18, text: DSTS			250, 516, 57, 18
# left: 316, width: 2, top: 521, height: 15, text: :			316, 521, 2, 15
# left: 328, width: 95, top: 516, height: 18, text: REISSUE			328, 516, 95, 18
# left: 432, width: 29, top: 517, height: 17, text: TO			432, 517, 29, 17
# left: 469, width: 45, top: 517, height: 16, text: ADD			469, 517, 45, 16
# left: 522, width: 46, top: 517, height: 17, text: AND			522, 517, 46, 17
# left: 576, width: 108, top: 517, height: 17, text: CORRECT			576, 517, 108, 17
# left: 693, width: 57, top: 517, height: 16, text: DATA			693, 517, 57, 16
# left: 123, width: 1062, top: 566, height: 183, text: nan			123, 566, 1062, 183
# left: 123, width: 1062, top: 566, height: 183, text: nan			123, 566, 1062, 183
# left: 125, width: 993, top: 566, height: 21, text: nan			125, 566, 993, 21
# left: 125, width: 114, top: 566, height: 21, text: LOCATION			125, 566, 114, 21
# left: 248, width: 59, top: 566, height: 17, text: DATA			248, 566, 59, 17
# left: 306, width: 10, top: 557, height: 39, text: :			306, 557, 10, 39
# left: 327, width: 11, top: 567, height: 16, text: 9			327, 567, 11, 16
# left: 347, width: 29, top: 567, height: 16, text: 1/4			347, 567, 29, 16
# left: 383, width: 23, top: 567, height: 16, text: MI			383, 567, 23, 16
# left: 414, width: 57, top: 567, height: 16, text: WNW			414, 567, 57, 16
# left: 596, width: 35, top: 567, height: 16, text: WY			596, 567, 35, 16
# left: 639, width: 68, top: 567, height: 16, text: IRREG			639, 567, 68, 16
# left: 716, width: 49, top: 567, height: 18, text: SEC:			716, 567, 49, 18
# left: 775, width: 3, top: 571, height: 15, text: :			775, 571, 3, 15
# left: 786, width: 71, top: 567, height: 20, text: PBHL			786, 567, 71, 20
# left: 852, width: 10, top: 557, height: 39, text: :			852, 557, 10, 39
# left: 866, width: 33, top: 567, height: 16, text: MD			866, 567, 33, 16
# left: 907, width: 48, top: 567, height: 16, text: 7732			907, 567, 48, 16
# left: 963, width: 43, top: 566, height: 17, text: TVD			963, 566, 43, 17
# left: 1014, width: 48, top: 566, height: 17, text: 7650			1014, 566, 48, 17
# left: 1072, width: 46, top: 566, height: 17, text: 1037			1072, 566, 46, 17
# left: 125, width: 960, top: 590, height: 19, text: nan			125, 590, 960, 19
# left: 125, width: 25, top: 591, height: 17, text: FT			125, 591, 25, 17
# left: 158, width: 13, top: 591, height: 17, text: S			158, 591, 13, 17
# left: 180, width: 22, top: 592, height: 16, text: 12			180, 592, 22, 16
# left: 211, width: 45, top: 591, height: 17, text: DEG			211, 591, 45, 17
# left: 264, width: 23, top: 592, height: 16, text: 24			264, 592, 23, 16
# left: 295, width: 39, top: 591, height: 17, text: MIN			295, 591, 39, 17
# left: 343, width: 23, top: 592, height: 16, text: 35			343, 592, 23, 16
# left: 374, width: 43, top: 591, height: 17, text: SEC			374, 591, 43, 17
# left: 421, width: 14, top: 583, height: 38, text: W			421, 583, 14, 38
# left: 454, width: 47, top: 592, height: 16, text: 1013			454, 592, 47, 16
# left: 509, width: 13, top: 591, height: 18, text: S			509, 591, 13, 18
# left: 530, width: 36, top: 592, height: 16, text: 223			530, 592, 36, 16
# left: 573, width: 19, top: 591, height: 17, text: W			573, 591, 19, 17
# left: 600, width: 36, top: 592, height: 17, text: 660			600, 592, 36, 17
# left: 644, width: 39, top: 591, height: 18, text: FSL			644, 591, 39, 18
# left: 690, width: 37, top: 592, height: 17, text: 660			690, 592, 37, 17
# left: 735, width: 45, top: 591, height: 17, text: FWL			735, 591, 45, 17
# left: 788, width: 44, top: 591, height: 17, text: SEC			788, 591, 44, 17
# left: 842, width: 136, top: 591, height: 17, text: 12-27N-114W			842, 591, 136, 17
# left: 986, width: 14, top: 591, height: 17, text: C			986, 591, 14, 17
# left: 1009, width: 33, top: 591, height: 17, text: SW			1009, 591, 33, 17
# left: 1051, width: 34, top: 590, height: 18, text: SW			1051, 590, 34, 18
# left: 123, width: 986, top: 616, height: 21, text: nan			123, 616, 986, 21
# left: 123, width: 62, top: 616, height: 21, text: ABHL			123, 616, 62, 21
# left: 193, width: 3, top: 621, height: 12, text: :			193, 621, 3, 12
# left: 205, width: 33, top: 616, height: 17, text: MD			205, 616, 33, 17
# left: 246, width: 48, top: 617, height: 16, text: 8700			246, 617, 48, 16
# left: 302, width: 42, top: 616, height: 17, text: TVD			302, 616, 42, 17
# left: 352, width: 48, top: 617, height: 17, text: 8543			352, 617, 48, 17
# left: 409, width: 47, top: 617, height: 17, text: 1037			409, 617, 47, 17
# left: 464, width: 26, top: 617, height: 16, text: FT			464, 617, 26, 16
# left: 497, width: 13, top: 616, height: 18, text: S			497, 616, 13, 18
# left: 520, width: 21, top: 617, height: 17, text: 12			520, 617, 21, 17
# left: 550, width: 45, top: 616, height: 18, text: DEG			550, 616, 45, 18
# left: 603, width: 24, top: 617, height: 17, text: 24			603, 617, 24, 17
# left: 635, width: 38, top: 617, height: 16, text: MIN			635, 617, 38, 16
# left: 682, width: 23, top: 617, height: 16, text: 35			682, 617, 23, 16
# left: 713, width: 44, top: 616, height: 18, text: SEC			713, 616, 44, 18
# left: 766, width: 12, top: 617, height: 16, text: E			766, 617, 12, 16
# left: 788, width: 47, top: 617, height: 17, text: 1013			788, 617, 47, 17
# left: 843, width: 12, top: 616, height: 18, text: S			843, 616, 12, 18
# left: 863, width: 36, top: 617, height: 17, text: 223			863, 617, 36, 17
# left: 908, width: 12, top: 617, height: 16, text: E			908, 617, 12, 16
# left: 928, width: 36, top: 617, height: 17, text: 660			928, 617, 36, 17
# left: 973, width: 39, top: 616, height: 17, text: FSL			973, 616, 39, 17
# left: 1019, width: 36, top: 617, height: 16, text: 660			1019, 617, 36, 16
# left: 1063, width: 46, top: 616, height: 17, text: FWL			1063, 616, 46, 17
# left: 843, width: 198, top: 649, height: 24, text: nan			843, 649, 198, 24
# left: 843, width: 39, top: 651, height: 22, text: Pie			843, 651, 39, 22
# left: 1008, width: 33, top: 649, height: 22, text: OF			1008, 649, 33, 22
# left: 703, width: 482, top: 679, height: 28, text: nan			703, 679, 482, 28
# left: 703, width: 116, top: 683, height: 24, text: MIN			703, 683, 116, 24
# left: 799, width: 21, top: 675, height: 40, text: f			799, 675, 21, 40
# left: 832, width: 112, top: 682, height: 23, text: GEOLOK			832, 682, 112, 23
# left: 949, width: 71, top: 681, height: 21, text: dC.AL			949, 681, 71, 21
# left: 1033, width: 66, top: 681, height: 21, text: RESE			1033, 681, 66, 21
# left: 1110, width: 75, top: 679, height: 25, text: ARON			1110, 679, 75, 25
# left: 589, width: 478, top: 713, height: 36, text: nan			589, 713, 478, 36
# left: 589, width: 72, top: 729, height: 20, text: (OVER)			589, 729, 72, 20
# left: 816, width: 109, top: 714, height: 25, text: CENTER			816, 714, 109, 25
# left: 962, width: 105, top: 713, height: 24, text: CASES			962, 713, 105, 24
# left: 124, width: 1003, top: 750, height: 20, text: nan			124, 750, 1003, 20
# left: 124, width: 1003, top: 750, height: 20, text: nan			124, 750, 1003, 20
# left: 124, width: 1003, top: 750, height: 20, text: nan			124, 750, 1003, 20
# left: 124, width: 16, top: 751, height: 16, text: ©			124, 751, 16, 16
# left: 148, width: 35, top: 754, height: 13, text: 1999			148, 754, 35, 13
# left: 189, width: 74, top: 754, height: 13, text: Petroleum			189, 754, 74, 13
# left: 269, width: 147, top: 754, height: 16, text: informalion’Tawights			269, 754, 147, 16
# left: 422, width: 29, top: 754, height: 13, text: t.0			422, 754, 29, 13
# left: 457, width: 36, top: 754, height: 13, text: d/b/a			457, 754, 36, 13
# left: 499, width: 26, top: 754, height: 13, text: IHS			499, 754, 26, 13
# left: 532, width: 51, top: 754, height: 16, text: Energy			532, 754, 51, 16
# left: 589, width: 46, top: 754, height: 14, text: Group			589, 754, 46, 14
# left: 727, width: 110, top: 750, height: 17, text: 12/31/1999			727, 750, 110, 17
# left: 964, width: 70, top: 751, height: 16, text: CARD#			964, 751, 70, 16
# left: 1042, width: 85, top: 750, height: 17, text: 0019-WY			1042, 750, 85, 17
# left: 0, width: 1208, top: 0, height: 803, text: nan
# left: 578, width: 96, top: 62, height: 18, text: nan
# left: 578, width: 96, top: 62, height: 18, text: nan
# left: 578, width: 96, top: 62, height: 18, text: nan
# left: 578, width: 96, top: 62, height: 18, text: REISSUE
# left: 124, width: 948, top: 87, height: 92, text: nan
# left: 125, width: 841, top: 87, height: 42, text: nan
# left: 125, width: 841, top: 87, height: 17, text: nan
# left: 125, width: 196, top: 87, height: 17, text: STATE: WYOMING
# left: 829, width: 137, top: 87, height: 17, text: 12-27N-114W
# left: 125, width: 817, top: 112, height: 17, text: nan SW
# left: 125, width: 220, top: 112, height: 17, text: COUNTY: SUBLETTE
# left: 828, width: 71, top: 112, height: 17, text: SE NW
# left: 124, width: 948, top: 136, height: 43, text: nan
# left: 124, width: 127, top: 136, height: 18, text: nan API: 49-035-:
# left: 829, width: 243, top: 136, height: 17, text: 1673 FSL 883 FWL SEC
# left: 125, width: 851, top: 161, height: 18, text: nan GAS
# left: 125, width: 261, top: 162, height: 17, text: FIELD: HOGSBACK UNIT
# left: 827, width: 95, top: 162, height: 17, text: STATUS:
# left: 124, width: 650, top: 186, height: 68, text: nan UNIT
# left: 124, width: 650, top: 186, height: 68, text: nan
# left: 124, width: 190, top: 186, height: 17, text: nan DG
# left: 124, width: 150, top: 186, height: 17, text: WELL CLASS:
# left: 125, width: 184, top: 211, height: 17, text: nan
# left: 125, width: 184, top: 211, height: 17, text: MOBIL OIL CORP
# left: 477, width: 297, top: 236, height: 18, text: nan
# left: 477, width: 238, top: 236, height: 18, text: T26X-12G HOGSBACK
# left: 124, width: 1005, top: 266, height: 11, text: nan
# left: 124, width: 1005, top: 266, height: 11, text: nan
# left: 124, width: 1005, top: 266, height: 11, text: nan
# left: 124, width: 951, top: 317, height: 120, text: nan
# left: 124, width: 566, top: 317, height: 20, text: nan GR
# left: 124, width: 566, top: 317, height: 20, text: nan
# left: 124, width: 527, top: 317, height: 20, text: SPUD 07/31/1999 COMP 09/23/1999 ELEV 7770
# left: 124, width: 934, top: 341, height: 46, text: nan
# left: 124, width: 934, top: 337, height: 31, text: nan TD : 8700 (08/20/1999) FM/TD MUDDY /SILT/ SH/ SD/ PBTD : 8540 TVD 8543 DTD 8700
# left: 124, width: 666, top: 366, height: 21, text: nan
# left: 124, width: 666, top: 362, height: 31, text: CONTR : CAZA DRILLING RIG # 72 (DIRECTIONALLY DRILLED)
# left: 124, width: 951, top: 391, height: 46, text: nan
# left: 124, width: 951, top: 391, height: 22, text: nan
# left: 120, width: 955, top: 387, height: 32, text: PROJ DEPTH/FM 7732 FRONTIER 2 PROJ TVD 7650 (ST APPD PMT: 06/10/1999) LEASE
# left: 128, width: 355, top: 416, height: 21, text: nan GAS
# left: 128, width: 301, top: 416, height: 21, text: TYPE: OTHER TARGET OBY:
# left: 124, width: 960, top: 466, height: 70, text: nan
# left: 124, width: 960, top: 466, height: 70, text: nan
# left: 124, width: 934, top: 466, height: 18, text: nan 8700 DTD COMP 09/23/1999 # 001 IPF OIL: BPD GAS: 2000 MCFD WTR: 0 BBL FTP 500
# left: 125, width: 959, top: 491, height: 22, text: nan NO
# left: 125, width: 631, top: 491, height: 21, text: PROD ZONE: PERF (FRONTIER 2) 7295-7588 PERF (MUDDY
# left: 124, width: 626, top: 516, height: 20, text: nan
# left: 124, width: 560, top: 516, height: 18, text: CORES OR DSTS REISSUE TO ADD AND CORRECT
# left: 693, width: 338, top: 492, height: 21, text: DATA /SILT/ SH/ SD/) 8138-8380
# left: 123, width: 1062, top: 566, height: 183, text: nan
# left: 123, width: 1062, top: 566, height: 183, text: nan
# left: 125, width: 993, top: 566, height: 21, text: nan 1037
# left: 125, width: 346, top: 557, height: 39, text: LOCATION DATA : 9 1/4 MI WNW
# left: 596, width: 466, top: 557, height: 39, text: WY IRREG SEC: PBHL : MD 7732 TVD 7650
# left: 125, width: 960, top: 583, height: 38, text: nan FT S 12 DEG 24 MIN 35 SEC W 1013 S 223 W 660 FSL 660 FWL SEC 12-27N-114W C SW SW
# left: 123, width: 986, top: 616, height: 21, text: nan FWL
# left: 123, width: 932, top: 616, height: 21, text: ABHL MD 8700 TVD 8543 1037 FT S 12 DEG 24 MIN 35 SEC E 1013 S 223 E 660 FSL 660
# left: 843, width: 39, top: 649, height: 24, text: nan Pie
# left: 1008, width: 33, top: 649, height: 22, text: OF
# left: 703, width: 482, top: 679, height: 28, text: nan
# left: 703, width: 482, top: 675, height: 40, text: MIN f GEOLOK dC.AL RESE ARON
# left: 816, width: 251, top: 713, height: 25, text: CENTER CASES
# left: 124, width: 459, top: 750, height: 20, text: nan nan nan © 1999 Petroleum informalion’Tawights t.0 d/b/a IHS Energy
# left: 589, width: 46, top: 713, height: 36, text: (OVER) nan Group
# left: 727, width: 110, top: 750, height: 17, text: 12/31/1999
# left: 964, width: 163, top: 750, height: 17, text: CARD# 0019-WY
#
# name:
# OPR:
# TWP: 	Range:
# LocationInfo:  SEC 12 QtrQtr: C SW SW 	LocationFootage:
# InitProd:
# ProdZone: PROD ZONE: PERF (FRONTIER 2) 7295-7588 PERF (MUDDY
# card#:
# DSTs: T26X-12G HOGSBACK COMP : 09/23/1999 ELEV : 7770 GR FM/TD : MUDDY /SILT/ SH/ SD/ RIG # 72 (DIRECTIONALLY : 7732 FRONTIER 2 PROJ TVD : 7650 OBY: GAS 09/23/1999 # 001 IPF OIL; 0 BPD GAS: (FRONTIER 2) 7295-7588 PERF (MUDDY ; REISSUE TO ADD AND CORRECT : 9 1/4 MI WNW WY IRREG 35 SEC W 1013 S 223 W 660 FSL TVD 8543 1037 FT S 12 DEG 24 MIN
# Casing:
# Formations: MOBIL OIL CORP  SPUD : 07/31/1999 TD : 8700 (08/20/1999) CONTR : CAZA PROJ DEPTH/FM TYPE; OTHER 8700 DTD COMP PROD ZONE: PERF CORES OR DSTS LOCATION DATA FT S 12 DEG 24 ABHL : MD 8700
