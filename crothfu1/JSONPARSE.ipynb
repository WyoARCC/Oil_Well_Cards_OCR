# %%
# Python program to read
# json file
 
import json
 
# Opening JSON file
f = open('/project/arcc-students/crothfu1/OilWellProject/Code/Slides/json/145-0204.json')
 
# returns JSON object as
# a dictionary
data = json.load(f)
for fig in range(0,10):
    print('word: '+str(fig))
    for i in range(0,4):
        print('x:' + str(data['textAnnotations'][1]['boundingPoly']['vertices'][i]['x']))
        print('y:' + str(data['textAnnotations'][1]['boundingPoly']['vertices'][i]['y']))

    
# Closing file
f.close()
# Out:
# word: 0
# x:21
# y:107
# x:53
# y:108
# x:53
# y:127
# x:21
# y:126
# word: 1
# x:21
# y:107
# x:53
# y:108
# x:53
# y:127
# x:21
# y:126
# word: 2
# x:21
# y:107
# x:53
# y:108
# x:53
# y:127
# x:21
# y:126
# word: 3
# x:21
# y:107
# x:53
# y:108
# x:53
# y:127
# x:21
# y:126
# word: 4
# x:21
# y:107
# x:53
# y:108
# x:53
# y:127
# x:21
# y:126
# word: 5
# x:21
# y:107
# x:53
# y:108
# x:53
# y:127
# x:21
# y:126
# word: 6
# x:21
# y:107
# x:53
# y:108
# x:53
# y:127
# x:21
# y:126
# word: 7
# x:21
# y:107
# x:53
# y:108
# x:53
# y:127
# x:21
# y:126
# word: 8
# x:21
# y:107
# x:53
# y:108
# x:53
# y:127
# x:21
# y:126
# word: 9
# x:21
# y:107
# x:53
# y:108
# x:53
# y:127
# x:21
# y:126
